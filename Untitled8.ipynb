# %% [markdown]
# <a href="https://colab.research.google.com/github/Saintcyberwarrior/Zero-shot_Knowledge_Distillation_Pytorch/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/da2so/Zero-shot_Knowledge_Distillation_Pytorch/blob/master/main.py
# Out:
# Cloning into 'main.py'...
# fatal: repository 'https://github.com/da2so/Zero-shot_Knowledge_Distillation_Pytorch/blob/master/main.py/' not found

# %%
# !git clone https://github.com/da2so/Zero-shot_Knowledge_Distillation_Pytorch
# Out:
# Cloning into 'Zero-shot_Knowledge_Distillation_Pytorch'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 75 (delta 17), reused 50 (delta 13), pack-reused 15
# Unpacking objects: 100% (75/75), done.

# %%
# !python3 /content/Zero-shot_Knowledge_Distillation_Pytorch/main.py
# Out:
# ------------------------------ ZSKD start ------------------------------
#
# ------------------------------ ZSKD end ------------------------------
# Traceback (most recent call last):
#   File "/content/Zero-shot_Knowledge_Distillation_Pytorch/main.py", line 56, in <module>
#     main()
#   File "/content/Zero-shot_Knowledge_Distillation_Pytorch/main.py", line 44, in main
#     student, save_root= zskd.build()
#   File "/content/Zero-shot_Knowledge_Distillation_Pytorch/ZSKD.py", line 98, in build
#     return self.student, save_root
# UnboundLocalError: local variable 'save_root' referenced before assignment

# %%
# !python3 /content/Zero-shot_Knowledge_Distillation_Pytorch/main.py
# Out:
# Traceback (most recent call last):
#   File "/content/Zero-shot_Knowledge_Distillation_Pytorch/main.py", line 56, in <module>
#     main()
#   File "/content/Zero-shot_Knowledge_Distillation_Pytorch/main.py", line 50, in main
#     S_trainer=s_trainer(args.dataset,save_root, teacher, student,args.s_save_path)
#   File "/content/Zero-shot_Knowledge_Distillation_Pytorch/trainer/student_train.py", line 27, in __init__
#     self.data_train= torchvision.datasets.ImageFolder(root = self.data_path,transform = test_trans)
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py", line 256, in __init__
#     is_valid_file=is_valid_file)
#   File "/usr/local/lib/python3.7/dist-packages/torchvision/datasets/folder.py", line 132, in __init__
#     raise RuntimeError(msg)
# RuntimeError: Found 0 files in subfolders of: /content/Zero-shot_Knowledge_Distillation_Pytorch/trainer/
# Supported extensions are: .jpg,.jpeg,.png,.ppm,.bmp,.pgm,.tif,.tiff,.webp

# %%
# !python3 /content/Zero-shot_Knowledge_Distillation_Pytorch/main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 	[365/1500] Loss: 0.20957596600055695
# 	[366/1500] Loss: 0.20950859785079956
# 	[367/1500] Loss: 0.20944006741046906
# 	[368/1500] Loss: 0.20937275886535645
# 	[369/1500] Loss: 0.20930537581443787
# 	[370/1500] Loss: 0.20923849940299988
# 	[371/1500] Loss: 0.20917223393917084
# 	[372/1500] Loss: 0.20910581946372986
# 	[373/1500] Loss: 0.20904013514518738
# 	[374/1500] Loss: 0.20897461473941803
# 	[375/1500] Loss: 0.2089100182056427
# 	[376/1500] Loss: 0.208845317363739
# 	[377/1500] Loss: 0.20878097414970398
# 	[378/1500] Loss: 0.2087160050868988
# 	[379/1500] Loss: 0.20865210890769958
# 	[380/1500] Loss: 0.20858736336231232
# 	[381/1500] Loss: 0.20852310955524445
# 	[382/1500] Loss: 0.20845884084701538
# 	[383/1500] Loss: 0.20839530229568481
# 	[384/1500] Loss: 0.2083318531513214
# 	[385/1500] Loss: 0.20826920866966248
# 	[386/1500] Loss: 0.208205908536911
# 	[387/1500] Loss: 0.20814356207847595
# ...

# %%
# !python3 /content/Zero-shot_Knowledge_Distillation_Pytorch/main.py
# Out:
# Files already downloaded and verified
# ------------------------------ Train student start ------------------------------
# Train - Epoch 1, Batch: 1, Loss: 0.331182
# Test Avg. Loss: 0.018190, Accuracy: 0.100000
# Train - Epoch 2, Batch: 1, Loss: 0.326364
# Test Avg. Loss: 0.018189, Accuracy: 0.105100
# Train - Epoch 3, Batch: 1, Loss: 0.326560
# Test Avg. Loss: 0.018188, Accuracy: 0.098400
# Train - Epoch 4, Batch: 1, Loss: 0.324620
# Test Avg. Loss: 0.018189, Accuracy: 0.108800
# Train - Epoch 5, Batch: 1, Loss: 0.324283
# Test Avg. Loss: 0.018193, Accuracy: 0.096300
# Train - Epoch 6, Batch: 1, Loss: 0.324007
# Test Avg. Loss: 0.018194, Accuracy: 0.096800
# Train - Epoch 7, Batch: 1, Loss: 0.323472
# Test Avg. Loss: 0.018212, Accuracy: 0.084000
# Train - Epoch 8, Batch: 1, Loss: 0.323488
# Test Avg. Loss: 0.018215, Accuracy: 0.087900
# Train - Epoch 9, Batch: 1, Loss: 0.323523
# Test Avg. Loss: 0.018211, Accuracy: 0.100600
# Train - Epoch 10, Batch: 1, Loss: 0.323420
# ...
